# %% [markdown]
# ## Q1 Guess the Output

# %%
a = [1, 2, 3]
a.append([4, 5])
print(len(a))

# %% [markdown]
# A. 3
# B. 4
# C. 5
# D. Error

# %% [markdown]
# ## Q2 Which method removes the last element from a list?
# A. remove()
# B. pop()
# C. delete()
# D. discard()

# %% [markdown]
# ## Q3 What does discard() do?
# A. Removes element and raises error
# B. Removes element safely
# C. Clears all data
# D. Delete the object

# %% [markdown]
# ## Q4 Guess the output

# %%
def f(x=[]):
    x.append(1)
    return x

print(f())
print(f())

# %% [markdown]
# ## Q5. Guess the output

# %% [raw]
# def f():
#     global x
#     x = 10
#
# f()
# print(x)

# %% [markdown]
# A. Error
# B. None
# C. 10
# D. None of the above

# %% [markdown]
# ## Q6 Which mode creates file but fails if file
# ## exists?
# A. w
# B. a
# C. x
# D. r+

# %% [markdown]
# ## Q7. Guess the output

# %%
print(10 == 10.0, 10 is 10.0)

# %% [markdown]
# A. True True
# B. False False
# C. True False
# D. False True

# %% [markdown]
# ## Q8. Guess the output

# %%
a = [1, 2, 3]
b = a
b.append(4)
print(a)

# %% [markdown]
# A. [1, 2, 3]
# B. [1, 2, 3, 4]
# C. Error
# D. [4]

# %% [markdown]
# ## Q9. Guess the Output

# %%
t = (1, [2, 3])
t[1].append(4)
print(t)

# %% [markdown]
# A. Error
# B. (1, [2, 3] )
# C. (1, [2, 3, 4])
# D. None of the above

# %% [markdown]
# ## Q10. Guess the Output

# %%
s = {1, 2, 3}
print(s.pop())

# %% [markdown]
# A. 1
# B. 3
# C. Error
# D. None of the above

# %% [markdown]
# ## Q11. Guess the Output

# %%
d = {1: 'a', True: 'b'}
print(d)
# Out:
# {1: 'b'}

# %% [markdown]
# A. {1: 'a', True: 'b'}
# B. {True: 'b'}
# C. {1: 'b'}
# D. Error
# E. None of the above

# %% [markdown]
# ## Q12. Guess the Output

# %%
def f():
    return [(i*i for i in range(3))]

print(f())
# Out:
# (<generator object f.<locals>.<genexpr> at 0x000001959BF00AD0>,)

# %% [markdown]
# A. List
# B. Tuple
# C. Set
# D. None of the above
